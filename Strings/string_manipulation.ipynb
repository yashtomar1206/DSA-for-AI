# %% [markdown]
# # String Manipulation
#  there are 8 types of string manipulation in python use in mostly in ai

# %% [markdown]
# # 1. Case conversion
# - lower()
# - upper()
# - title()
# - capitalize()
# - swapcase()

# %% [markdown]
# # 2. Whitespace handling
# - strip()
# - Istrip() / rstrip()

# %% [markdown]
# # 3. Searching & Sorting
# - find
# - startwith()
# - endwith()

# %% [markdown]
# # 4. Validation checks
# - isdigit()
# - isalpha
# - isalnum()
# - islower()
# - isspace()

# %% [markdown]
# # 5. Splitting & Joining
# - split(sep)
# - join(int)

# %% [markdown]
# # 6. replacement
#  - replace(old, new)

# %% [markdown]
# # 7. Counting& measuring
# - lens(s)
# - count(sub)

# %% [markdown]
# # 8. Formatting
# - f - string
